# %% [markdown]
# # #Q.1 Draw 100 samples from uni-variate Normal distribution, plot its histogram. Compute pdf for univariate normal distribution and compare it with histogram. Repeat experiment with 500, 1000 datapoints.

# %%
#100samples
import numpy as np

mu, sigma = 0,1 # mean and standard deviation
s = np.random.normal(mu, sigma, 12)

# %%
#500samples
import numpy as np

mu, sigma = 0,1 # mean and standard deviation
s = np.random.normal(mu, sigma, 500)

# %%
#1000samples
import numpy as np

mu, sigma = 0,1 # mean and standard deviation
s = np.random.normal(mu, sigma, 1000)

# %%
#histogram of respective samples
import matplotlib.pyplot as plt


count, bins, ignored = plt.hist(s, 30, density=True)
#plt.plot(bins, 1/(sigma * np.sqrt(2 * np.pi)) *np.exp( - (bins - mu)**2 / (2 * sigma**2) ),linewidth=2, color='r')
print("Sample size =1000")
plt.show()
# Out:
# Sample size =1000

# %%
#pdf of respective samples
import matplotlib.pyplot as plt


#count, bins, ignored = plt.hist(s, 30, density=True)
plt.plot(bins, 1/(sigma * np.sqrt(2 * np.pi)) *np.exp( - (bins - mu)**2 / (2 * sigma**2) ),linewidth=2, color='r')
print("Sample size =100")
plt.show()
# Out:
# Sample size =100

# %%
#histogram and pdf compared
import matplotlib.pyplot as plt


count, bins, ignored = plt.hist(s, 30, density=True)
plt.plot(bins, 1/(sigma * np.sqrt(2 * np.pi)) *np.exp( - (bins - mu)**2 / (2 * sigma**2) ),linewidth=2, color='r')
print("Sample size =1000")
plt.show()
# Out:
# Sample size =1000

# %% [markdown]
# # #Q2.Draw 100 samples from bi-variate Normal distribution. Repeat experiment 1.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import multivariate_normal
from mpl_toolkits.mplot3d import Axes3D

#Parameters to set
mu_x = 0
variance_x = 1

mu_y = 0
variance_y = 1

#Create grid and multivariate normal
x = np.linspace(-3,3,500)
y = np.linspace(-3,3,500)
X, Y = np.meshgrid(x,y)
pos = np.empty(X.shape + (2,))
pos[:, :, 0] = X; pos[:, :, 1] = Y
rv = multivariate_normal([mu_x, mu_y], [[variance_x, 0], [0, variance_y]])

#Make a 3D plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(X, Y, rv.pdf(pos),linewidth=0, alpha = 0.5)
ax.set_xlabel('X axis')
ax.set_ylabel('Y axis')
ax.set_zlabel('Z axis')
mean = [0,0]
cov = [[1,0],[0,1]]
a = np.random.multivariate_normal(mean, cov,1000)
x_new = [i[0] for i in a]
y_new = [i[1] for i in a]
data = [(i[0], i[1]) for i in a]
unique_data = list(set(data))
z_new = [data.count(i)/10000 for i in unique_data]
ax.bar3d(x_new, y_new, z_new,  np.ones(len(y_new)), np.ones(len(x_new)), np.zeros(len(z_new)),  color='red')
print("Sample size 1000")
plt.show()
# Out:
# Sample size 1000

# %% [markdown]
# # #Q3. Implement central limit theorem.Draw 12 samples from Uni[0,1] as a sample population and perform CLT. Observe the distribution of sample means.

# %%
from numpy.random import seed
from numpy.random import randint
from numpy import mean
# seed the random number generator, so that the experiment is #replicable
seed(1)
# generate a sample of men's weights
weights = randint(60, 90, 50)
print(weights)
print('The average weight is {} kg'.format(mean(weights)))
# Out:
# [65 71 72 68 69 71 65 75 60 76 61 72 67 73 88 66 85 78 80 65 78 80 71 88
#  70 88 89 74 78 64 83 83 69 77 83 60 82 73 69 69 67 89 82 85 61 60 88 77
#  68 84]
# The average weight is 74.32 kg

# %%
import matplotlib.pyplot as plt
# seed the random number generator, so that the experiment is replicable
seed(1)
# calculate the mean of 50 men's weights 1000 times
means = [mean(randint(60, 90, 50)) for _i in range(1000)]
# plot the distribution of sample means
plt.hist(means)
plt.show()
print('The mean of the sample means is {}'.format(mean(means)))
# Out:
# The mean of the sample means is 74.54001999999998

# %%
#n=80
import matplotlib.pyplot as plt
# seed the random number generator, so that the experiment is replicable
seed(1)
# calculate the mean of 50 men's weights 1000 times
means = [mean(randint(60, 90, 80)) for _i in range(1000)]
# plot the distribution of sample means
plt.hist(means)
plt.show()
print('The mean of the sample means is {}'.format(mean(means)))
# Out:
# The mean of the sample means is 74.556

# %%
#n=90
import matplotlib.pyplot as plt
# seed the random number generator, so that the experiment is replicable
seed(1)
# calculate the mean of 50 men's weights 1000 times
means = [mean(randint(60, 90, 90)) for _i in range(1000)]
# plot the distribution of sample means
plt.hist(means)
plt.show()
print('The mean of the sample means is {}'.format(mean(means)))
# Out:
# The mean of the sample means is 74.54403333333335

# %%
#n=100
import matplotlib.pyplot as plt
# seed the random number generator, so that the experiment is replicable
seed(1)
# calculate the mean of 50 men's weights 1000 times
means = [mean(randint(60, 90, 100)) for _i in range(1000)]
# plot the distribution of sample means
plt.hist(means)
plt.show()
print('The mean of the sample means is {}'.format(mean(means)))
# Out:
# The mean of the sample means is 74.54565000000001

# %%
#histogram of 12 samples
mu = 0
sigma = 1
means = []
for i in range(1000):
    samples = np.random.random(12)
    means.append(np.average(samples))
final_sample = [(i-0.5)*12  for i in means]     #applying the central limit theorem

count, bins, ignored = plt.hist(final_sample,20, density=True)
plt.plot(bins, 1/(sigma * np.sqrt(2 * np.pi)) * np.exp( - (bins - mu)**2 / (2 * sigma**2) ),linewidth=2, color='maroon')
plt.show()

# %% [markdown]
# # #Q4.Use Box-Muller method to achieve Normal distribution.

# %%
from numpy import random, sqrt, log, sin, cos, pi
from pylab import show,hist,subplot,figure

# transformation function
def gaussian(u1,u2):
    z1 = sqrt(-2*log(u1))*cos(2*pi*u2)
    z2 = sqrt(-2*log(u1))*sin(2*pi*u2)
    return z1,z2

# uniformly distributed values between 0 and 1
u1 = random.rand(1000)
u2 = random.rand(1000)

# run the transformation
z1,z2 = gaussian(u1,u2)

# plotting the values before and after the transformation
figure()
subplot(221) # the first row of graphs
hist(u1, color='skyblue')     # contains the histograms of u1 and u2 
subplot(222)
hist(u2, color='purple')
subplot(223) # the second contains
hist(z1, color='skyblue')     # the histograms of z1 and z2
subplot(224)
hist(z2, color='purple')
show()
